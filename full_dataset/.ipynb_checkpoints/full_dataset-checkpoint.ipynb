# %%
import pandas as pd

# %%
pd.set_option('display.max_rows',None,'display.max_columns',None)

# %%
# !ls
# Out:
# full_dataset.ipynb  result_current.csv	result-eps.csv	result-rev.csv
# result-bvps.csv     result-de-.csv	result-fcf.csv	result-roi.csv

# %%
de = pd.read_csv('result-de-.csv',index_col=0)

# %%
current = pd.read_csv('result_current.csv',index_col=0)

# %%
#let's change the curren ratio column name, we did not change it before.
current.columns =['current']

# %%
roi = pd.read_csv('result-roi.csv',index_col=0)

# %%
eps = pd.read_csv('result-eps.csv',index_col=0)

# %%
rev = pd.read_csv('result-rev.csv',index_col=0)

# %%
bvps = pd.read_csv('result-bvps.csv',index_col=0)

# %%
fcf = pd.read_csv('result-fcf.csv',index_col=0)

# %%
data = pd.concat([de,current],axis=1,keys=['DE ratio','Current','ROI'])
data
# Out:
#        DE ratio    Current
#       D/E ratio 2020-09-30
# AAPL       True       True
# MSFT       True       True
# AMZN       True       True
# GOOG       True       True
# FB         True       True
# TSLA       True       True
# BRK.A      True      False
# V          True       True
# JNJ        True       True
# WMT        True      False
# JPM       False      False
# MA         True       True
# PG         True      False
# UNH        True      False
# DIS        True       True
# NVDA       True       True
# HD        False       True
# PYPL       True       True
# BAC       False      False
# VZ         True       True
# ADBE       True       True
# CMCSA      True      False
# NFLX       True       True
# KO         True       True
# NKE        True       True
# MRK        True       True
# PEP       False      False
# T          True      False
# PFE        True       True
# INTC       True       True
# CRM        True       True
# ABT        True       True
# ORCL      False       True
# ABBV      False      False
# CSCO       True       True
# TMO        True       True
# AVGO       True       True
# XOM        True      False
# ACN        True       True
# QCOM       True       True
# COST       True       True
# CVX        True       True
# LLY       False       True
# MCD       False       True
# DHR        True       True
# MDT        True       True
# NEE        True      False
# TXN        True       True
# HON        True       True
# UPS       False       True
