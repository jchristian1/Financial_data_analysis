# %%
import pandas as pd

# %%
## Let's see the whole dataset
pd.set_option("display.max_rows",None,"display.max_columns",None)

# %%
## Let's load our current ratio dataset
current = pd.read_csv("50-current-ratio.csv",index_col=0)
current
# Out:
#             AAPL  MSFT  AMZN   GOOG     FB  TSLA  BRK.A     V   JNJ   WMT  \
# 2020-09-30  1.36  2.53  1.11   3.41   5.51  1.64   0.27  1.91  1.48   NaN
# 2020-06-30  1.47  2.52  1.18   3.41   6.03  1.25   0.30  1.55  1.25   NaN
# 2020-03-31  1.50  2.90  1.08   3.66   4.60  1.24   0.33  1.25  1.31   NaN
# 2019-12-31  1.60  2.80  1.10   3.37   4.40  1.14   0.39  1.27  1.26   NaN
# 2019-09-30  1.54  2.85  1.10   3.78   4.66  1.08   0.44  1.56  1.26   NaN
# 2019-06-30  1.51  2.53  1.10   3.99   4.47  1.06   0.34  1.69  1.33   NaN
# 2019-03-31  1.32  2.97  1.09   3.96   5.38  0.83   0.28  1.63  1.44   NaN
# 2018-12-31  1.30  3.12  1.10   3.92   7.19  0.83   0.29  1.50  1.47   NaN
# 2018-09-30  1.13  2.92  1.08   4.14   9.00  0.81   0.31  1.61  1.72   NaN
# 2018-06-30  1.31  2.90  1.07   4.15  10.67  0.73   0.40  1.69  1.65   NaN
# 2018-03-31  1.46  3.40  1.06   4.87   9.91  0.74   0.37  1.94  1.58   NaN
# 2017-12-31  1.24  2.89  1.04   5.14  12.92  0.86   0.28  2.07  1.41   NaN
# ...

# %%
## Let's make the date our y index
current.index
# Out:
# Index(['2020-09-30', '2020-06-30', '2020-03-31', '2019-12-31', '2019-09-30',
#        '2019-06-30', '2019-03-31', '2018-12-31', '2018-09-30', '2018-06-30',
#        ...
#        '2007-05-31', '2007-02-28', '2006-11-30', '2006-08-31', '2006-05-31',
#        '2006-02-28', '2005-11-30', '2005-08-31', '2005-05-31', '2005-02-28'],
#       dtype='object', length=191)

# %%
##let's format our index as datetime
current.index = pd.to_datetime(current.index)
current.index
# Out:
# DatetimeIndex(['2020-09-30', '2020-06-30', '2020-03-31', '2019-12-31',
#                '2019-09-30', '2019-06-30', '2019-03-31', '2018-12-31',
#                '2018-09-30', '2018-06-30',
#                ...
#                '2007-05-31', '2007-02-28', '2006-11-30', '2006-08-31',
#                '2006-05-31', '2006-02-28', '2005-11-30', '2005-08-31',
#                '2005-05-31', '2005-02-28'],
#               dtype='datetime64[ns]', length=191, freq=None)

# %%
## Let's sort the data by date
current.sort_index(ascending=False, inplace=True)
current
# Out:
#             AAPL  MSFT  AMZN   GOOG     FB  TSLA  BRK.A     V   JNJ   WMT  \
# 2020-11-30   NaN   NaN   NaN    NaN    NaN   NaN    NaN   NaN   NaN   NaN
# 2020-10-31   NaN   NaN   NaN    NaN    NaN   NaN    NaN   NaN   NaN  0.84
# 2020-09-30  1.36  2.53  1.11   3.41   5.51  1.64   0.27  1.91  1.48   NaN
# 2020-08-31   NaN   NaN   NaN    NaN    NaN   NaN    NaN   NaN   NaN   NaN
# 2020-07-31   NaN   NaN   NaN    NaN    NaN   NaN    NaN   NaN   NaN  0.79
# 2020-06-30  1.47  2.52  1.18   3.41   6.03  1.25   0.30  1.55  1.25   NaN
# 2020-05-31   NaN   NaN   NaN    NaN    NaN   NaN    NaN   NaN   NaN   NaN
# 2020-04-30   NaN   NaN   NaN    NaN    NaN   NaN    NaN   NaN   NaN  0.77
# 2020-03-31  1.50  2.90  1.08   3.66   4.60  1.24   0.33  1.25  1.31   NaN
# 2020-02-29   NaN   NaN   NaN    NaN    NaN   NaN    NaN   NaN   NaN   NaN
# 2020-01-31   NaN   NaN   NaN    NaN    NaN   NaN    NaN   NaN   NaN  0.80
# 2019-12-31  1.60  2.80  1.10   3.37   4.40  1.14   0.39  1.27  1.26   NaN
# ...

# %%
## let's remove the old data
current = current.loc['2010-01-01':]
current
# Out:
# /tmp/ipykernel_16736/3246972979.py:2: FutureWarning: Value based partial slicing on non-monotonic DatetimeIndexes with non-existing keys is deprecated and will raise a KeyError in a future Version.
#   current = current.loc['2010-01-01':]
#             AAPL  MSFT  AMZN   GOOG     FB  TSLA  BRK.A     V   JNJ   WMT  \
# 2020-11-30   NaN   NaN   NaN    NaN    NaN   NaN    NaN   NaN   NaN   NaN
# 2020-10-31   NaN   NaN   NaN    NaN    NaN   NaN    NaN   NaN   NaN  0.84
# 2020-09-30  1.36  2.53  1.11   3.41   5.51  1.64   0.27  1.91  1.48   NaN
# 2020-08-31   NaN   NaN   NaN    NaN    NaN   NaN    NaN   NaN   NaN   NaN
# 2020-07-31   NaN   NaN   NaN    NaN    NaN   NaN    NaN   NaN   NaN  0.79
# 2020-06-30  1.47  2.52  1.18   3.41   6.03  1.25   0.30  1.55  1.25   NaN
# 2020-05-31   NaN   NaN   NaN    NaN    NaN   NaN    NaN   NaN   NaN   NaN
# 2020-04-30   NaN   NaN   NaN    NaN    NaN   NaN    NaN   NaN   NaN  0.77
# ...

# %%
current.resample('Q', convention='end').agg('mean').transpose()
# Out:
#        2010-03-31  2010-06-30  2010-09-30  2010-12-31  2011-03-31  2011-06-30  \
# AAPL         2.64        2.31        2.01        1.85        1.93        1.75
# MSFT         2.06        2.13        2.30        2.46        2.76        2.60
# AMZN         1.53        1.55        1.50        1.33        1.46        1.40
# GOOG        10.65        6.12        4.63        4.16        4.64        5.96
# FB           0.00        0.00        0.00        5.77        0.00        0.00
# TSLA         0.00        1.31        3.48        2.76        2.01        3.01
# BRK.A        0.37        0.38        0.41        0.45        0.45        0.48
# V            2.58        2.83        2.50        2.54        2.77        2.70
# JNJ          2.10        2.27        2.45        2.05        2.05        2.51
# WMT          0.87        0.80        0.81        0.87        0.89        0.90
# JPM          0.94        0.95        0.94        0.96        0.95        0.96
# ...

# %%
## Let's get Last period of current ratio by company
current.resample('Q', convention='end').agg('mean').transpose()['2020-09-30']
# Out:
# AAPL     1.36
# MSFT     2.53
# AMZN     1.11
# GOOG     3.41
# FB       5.51
# TSLA     1.64
# BRK.A    0.27
# V        1.91
# JNJ      1.48
# WMT      0.79
# JPM      0.88
# MA       1.86
# PG       0.87
# UNH      0.82
# DIS      1.32
# NVDA     6.09
# HD       1.30
# PYPL     1.38
# BAC      0.87
# VZ       1.07
# ADBE     1.44
# CMCSA    0.93
# NFLX     1.24
# KO       1.13
# NKE      2.55
# MRK      1.30
# PEP      0.93
# T        0.84
# PFE      1.40
# INTC     1.66
# CRM      1.15
# ABT      1.70
# ORCL     2.66
# ABBV     0.95
# CSCO     1.72
# TMO      2.93
# AVGO     2.04
# XOM      0.86
# ACN      1.40
# QCOM     2.14
# COST     1.13
# CVX      1.26
# LLY      1.36
# MCD      1.07
# DHR      2.08
# MDT      1.87
# NEE      0.57
# TXN      4.24
# HON      1.64
# UPS      1.29
# Name: 2020-09-30 00:00:00, dtype: float64

# %%
result = col > 1
